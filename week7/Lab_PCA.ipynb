# %% [markdown]
# # Lab: PCA

# %% [markdown]
# ### Create Data

# %%
#dummy regression data
import numpy as np
from sklearn.datasets import make_regression
X, y = make_regression(n_features=64, effective_rank=15 ,random_state=0, shuffle=False, n_samples=200)
X.shape
# Out:
# (200, 64)

# %% [markdown]
# ### E3.1 compute PCA
# see https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

pca = PCA()
principalComponents = pca.fit_transform(X,y)

principalComponents.shape
# Out:
# (200, 64)

# %% [markdown]
# ### E3.2 Plot Eigen Values

# %%
import matplotlib.pyplot as plt

#plt.scatter(principalComponents[:,0],  principalComponents[:,1], c=y );

#plt.plot(pca.explained_variance_);
plt.plot(pca.singular_values_);

# %% [markdown]
# ### E3.3 select a $\lambda$ cut-off and project to new base

# %%
cut_off = 30
pca_new = PCA (n_components= cut_off)
pca_new.fit_transform(X,y)
# Out:
# PCA(n_components=30)

# %%
plt.plot(pca_new.explained_variance_);

# %%
plt.plot(pca_new.singular_values_);
